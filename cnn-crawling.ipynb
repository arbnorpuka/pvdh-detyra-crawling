# %%
import requests # type: ignore
from bs4 import BeautifulSoup # type: ignore
import re
import csv
from concurrent.futures import ThreadPoolExecutor, as_completed

def get_article_info(article_url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }
    try:
        response = requests.get(article_url, headers=headers)
        response.raise_for_status()  # Raise an error for bad status codes
    except requests.RequestException as e:
        print(f"Failed to retrieve article: {article_url}. Error: {e}")
        return None

    response.encoding = response.apparent_encoding
    soup = BeautifulSoup(response.content, "html.parser")

    title = soup.find("h1", class_="headline__text")
    title = title.get_text(strip=True) if title else "No title found"

    author = soup.find("span", class_="byline__name") or soup.find("meta", {"name": "author"})
    author = author.get_text(strip=True) if author and hasattr(author, "get_text") else author["content"] if author else "No author listed"

    date = soup.find("div", class_="timestamp vossi-timestamp")
    if date:
        date_text = date.get_text(strip=True)
        date_match = re.search(r"\b[A-Za-z]{3}\s[A-Za-z]+\s\d{1,2},\s\d{4}\b", date_text)
        date = date_match.group(0) if date_match else "No date found"
    else:
        date = "No date found"

    paragraphs = soup.find_all("p")
    summary = " ".join(p.get_text(strip=True) for p in paragraphs[:2])

    reading_time = soup.find("div", class_="headline__sub-description")
    reading_time = reading_time.get_text(strip=True) if reading_time else ""

    return {
        "title": title,
        "author": author,
        "summary": summary,
        "published_date": date,
        "reading_time": reading_time,
        "url": article_url
    }

def scrape_cnn_articles():
    base_url = "https://edition.cnn.com"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
    }

    try:
        response = requests.get(base_url, headers=headers)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f"Failed to retrieve homepage. Error: {e}")
        return []

    soup = BeautifulSoup(response.content, "html.parser")
    headlines = soup.find_all("span", class_="container__headline-text")

    article_links = []
    for headline in headlines:
        parent_link = headline.find_parent("a", href=True)
        if parent_link and parent_link['href']:
            article_url = f"{base_url}{parent_link['href']}" if parent_link['href'].startswith('/') else parent_link['href']
            article_links.append(article_url)

    return article_links

def save_to_csv(data, filename="cnn_articles.csv"):
    with open(filename, mode="w", newline='', encoding="utf-8") as file:
        writer = csv.DictWriter(file, fieldnames=["title", "author", "summary", "published_date", "reading_time", "url"])
        writer.writeheader()
        writer.writerows(data)

if __name__ == "__main__":
    article_links = scrape_cnn_articles()
    scraped_data = []
    max_articles = 100

    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(get_article_info, url): url for url in article_links[:max_articles]}
        for future in as_completed(futures):
            article_info = future.result()
            if article_info:
                scraped_data.append(article_info)
                print(f"Scraped article: {article_info['title']}")

    if scraped_data:
        save_to_csv(scraped_data)
        print(f"Scraped {len(scraped_data)} articles and saved to cnn_articles.csv.")
    else:
        print("No articles were scraped.")
# Out:
# Scraped article: Can New York Yankees recover from last-gasp World Series Game 1 loss against Los Angeles Dodgers in Game 2?
# Scraped article: Israel launched strikes on Iran in a retaliatory attack. Here’s what we know
# Scraped article: Russian strike on Ukrainian hospital used to treat soldiers kills at least five
# Scraped article: Airline cracks down on ‘gate lice’ who skip the line
# Scraped article: Georgia’s pro-Western president condemns ‘troubling incidents of violence’ at polling stations with crucial vote underway
# Scraped article: The rape claims that tie the Menendez case to Menudo: ‘There might be other victims,’ doc producer says
# Scraped article: With worst-case scenario averted for now, White House and Harris campaign still face a serious risk in Middle East conflict
# Scraped article: Israel launched strikes on Iran in a retaliatory attack. Here’s what we know
# Scraped article: No title found
# Scraped article: Retired colonel explains significance of Israel’s strike against Iran
# Scraped article: The US wants this to be ‘the end’ of direct Israel-Iran fire. It may be too soon to tell
# Scraped article: Several explosions heard in Tehran, say Iranian state media
# Scraped article: Israel raids north Gaza hospital as UN warns ‘darkest moment’ is unfolding in the strip
# Scraped article: Why these Republicans think voting against Trump could save the GOP
# Scraped article: Fact check: Trump revives his lie that schools are secretly sending children for gender-affirming surgeries
# Scraped article: Hear Trump’s apology for arriving almost 3 hours late to rally
# Scraped article: No title found
# Scraped article: No title found
# Scraped article: Harry Enten: Electoral College could be a relative blowout despite historically tight polls
# Scraped article: Georgia’s ruling party wins pivotal election, early results show, as opposition parties cry foul
# Scraped article: Russian strike on Ukrainian hospital used to treat soldiers kills at least five
# Scraped article: Catch up on today’s global news
# Scraped article: Airline cracks down on ‘gate lice’ who skip the line
# Scraped article: SpaceX Crew-8 astronaut hospitalized with ‘medical issue’ after splashdown has been released, NASA says
# Scraped article: Iceland embraced a shorter work week. Here’s how it turned out
# Scraped article: New drone footage reveals rare flooding in Sahara
# Scraped article: She was the oldest living American. This was her secret to reaching 115
# Scraped article: Scientists say skeletal remains found in castle well belong to figure from 800-year-old saga
# Scraped article: The Washington Post is in deep turmoil as Bezos remains silent on non-endorsement
# Scraped article: NASA chief calls for investigation into report that Musk and Putin have spoken regularly
# Scraped article: 124 killed as Sudanese paramilitary group attacks village, doctors and activists say
# Scraped article: Hear what Trump told Joe Rogan his plans are for RFK Jr.
# Scraped article: ‘What the f**k to do with them?’ Russian soldiers heard condemning North Korean recruits in intercepted audio
# Scraped article: An 11-year-old girl played dead before escaping after 5 family members were killed at their Washington state home
# Scraped article: Los Angeles Dodgers’ Freddie Freeman launches himself into history with dramatic grand slam to win Game 1 of the World Series
# Scraped article: Can New York Yankees recover from last-gasp World Series Game 1 loss against Los Angeles Dodgers in Game 2?
# Scraped article: Inter Miami beats Atlanta United in Lionel Messi’s MLS playoff debut
# Scraped article: Commonwealth leaders say ‘time has come’ for discussion on UK slavery reparations
# Scraped article: Former Sports Illustrated model says she was groped by Trump in 1990s while Epstein watched
# Scraped article: Man sentenced to life after ‘catfishing’ at least 70 minors and driving a 12-year-old to take her own life
# Scraped article: Groundbreaking telescope reveals first piece of new cosmic map
# Scraped article: The rape claims that tie the Menendez case to Menudo: ‘There might be other victims,’ doc producer says
# Scraped article: She connected on Instagram with a guy who lived in another country. Then they decided to meet up
# Scraped article: Black rhino: Back from the brink
# Scraped article: Tiny house with elaborate – and erotic – frescoes unearthed at Pompeii
# Scraped article: Most space travelers face the same debilitating ailment. The experience of 4 civilian astronauts could offer answers
# Scraped article: A ring found among the debris of Florida’s recent hurricanes awaits its owner
# Scraped article: Witches walk among us — but they’re not like the fictional ones you grew up with
# Scraped article: ‘Proof of how hard I fought’: Why Olivia Munn chose to show her mastectomy scars in new Skims campaign
# Scraped article: Prince William’s Earthshot Prize reveals celebrity line-up for awards night
# Scraped article: New abortion ad features mother who says she was forced to deliver a baby doctors knew would die
# Scraped article: The mysteries — and sometimes miracles — of the fertility fight
# Scraped article: Stunning fossil trapped in amber reveals previously unknown species that lived during the time of dinosaurs
# Scraped article: Lost Silk Road cities mapped using remote sensing
# Scraped article: World’s largest arthropod lived 300 million years ago. Now, fossils show what it really looked like
# Scraped article: A giant meteorite boiled the oceans 3.2 billion years ago. Scientists say it was a ‘fertilizer bomb’ for life
# Scraped article: Peer inside the underwater volcanic caves where life thrives
# Scraped article: Europe’s secret season for travel starts now
# Scraped article: He served with the US Army in Iraq. Now he’s one of Asia’s top chefs and a Netflix ‘Culinary Class Wars’ judge
# Scraped article: ‘I want to be here for the rest of my life’: Why this man swapped San Francisco for Colombia
# Scraped article: The Full English: How a greasy feast came to define and divide a nation
# Scraped article: The magical white stone wonderland with effervescent bathing pools
# Scraped article: What the rising popularity of Yemeni coffee shops says about third places
# Scraped article: Jury awards Apple $250 in design patent lawsuit against Masimo
# Scraped article: Why Nike, Starbucks and Boeing have lost their magic
# Scraped article: Amazon Prime introduces a new benefit to save on gas
# Scraped article: US businesses are suffering from election uncertainty — and it could be hurting the economy
# Scraped article: These are 2024’s top trending Halloween costumes, according to Google
# Scraped article: Keurig Dr Pepper will buy energy drink maker Ghost for more than $1 billion
# Scraped article: Look of the Week: Zendaya pays tribute to Cher in shimmering vintage gown
# Scraped article: Painting by AI robot Ai-Da could fetch more than $120,000 at auction
# Scraped article: Striking photographs document environmental decay on world’s largest lake
# Scraped article: Curators are unraveling the mysteries of the belated art icon Tamara de Lempicka
# Scraped article: Super-thin skyscraper, just one apartment wide, planned for Dubai
# Scraped article: Meet Rojé Stona, an Olympic track and field champion with dreams of playing in the NFL
# Scraped article: Can New York Yankees recover from last-gasp World Series Game 1 loss against Los Angeles Dodgers in Game 2?
# Scraped article: Inter Miami beats Atlanta United in Lionel Messi’s MLS playoff debut
# Scraped article: Los Angeles Dodgers’ Freddie Freeman launches himself into history with dramatic grand slam to win Game 1 of the World Series
# Scraped article: Miami Dolphins quarterback Tua Tagovailoa cleared to return and will play Sunday against Arizona Cardinals
# Scraped article: USF men’s head basketball coach Amir Abdur-Rahim dead at 43
# Scraped article: Madison Square Garden versus the White House Ellipse: where Trump and Harris are making their final pitches
# Scraped article: Trump says he’s open to eliminating income taxes and repeats ‘enemy from within’ rhetoric on podcast with Joe Rogan
# Scraped article: Chinese hackers targeted Trump and Vance’s phone data
# Scraped article: US intelligence assesses Russian operatives behind fake video showing Pennsylvania ballots being destroyed
# Scraped article: NY Republican in critical House race spent huge sums of campaign cash on steakhouses, booze, Ubers and a foreign hostel
# Scraped article: More straight couples are calling each other partner. Here’s why
# Scraped article: How long can you stand like a flamingo? The answer may reflect your age, new study says
# Scraped article: 5 ways to support your friends with cancer, according to CNN’s Sara Sidner
# Scraped article: What experts say about taking psilocybin as an alternative treatment for depression
# Scraped article: Does your teen consume protein supplements? Here’s what experts say
# Scraped article: X changed its terms of service to let its AI train on everyone’s posts. Now users are up in arms
# Scraped article: Elon Musk says he’ll fix the government under Trump. His track record paints a different picture
# Scraped article: Meta fires employees for spending food allowances on personal items like acne pads and wine glasses
# Scraped article: Olaf Eliasson’s Shadows Traveling on the Sea of the Day in Qatar (Photos)
# Scraped article: Lions prowl South Africa’s ‘wildest golf course’
# Scraped article: Inside Lusail, Qatar’s ‘city of the future’
# Scraped article: Ayobola Kekere-Ekun’s vibrant artworks
# Scraped article: Grove XXIII: Inside Michael Jordan’s ultra-exclusive golf club
# Scraped article: In pictures: award-winning wildlife photographer Greg du Toit
# Scraped article: Swiping right ahead of the election: Popular dating apps have new features to show off political views
# Scraped 100 articles and saved to cnn_articles.csv.
